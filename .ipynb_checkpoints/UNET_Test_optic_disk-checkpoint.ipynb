# %%
from unet_project.image_utils import ImageUtils
from unet_project.data_augmentation import DataAugmentation
from unet_project.u_net import Unet
from unet_project.create_patches import PatchesCreator
from skimage.io import imshow
from matplotlib import pyplot as plt
import numpy as np
import cv2
from keras.callbacks import EarlyStopping, ModelCheckpoint
from skimage.io import imshow
from matplotlib import pyplot as plt
import random
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
path_to_imgs = '/home/ajuska/Dokumenty/Skola/diplomka/disk_data/imgs/'
path_to_masks = '/home/ajuska/Dokumenty/Skola/diplomka/disk_data/masks/'
img_height = 224
img_width = 224
img_channels = 3

image_utils = ImageUtils(path_to_imgs, path_to_masks, img_height, img_width)
imgs_masks = image_utils.get_preprocessed_images()

data_augmentor = DataAugmentation(imgs_masks, how_many=1)
aug_imgs, aug_masks = data_augmentor.extend_database()

trainX = [cv2.resize(x, (img_height, img_width)) for x in aug_imgs]
trainY = [cv2.resize(x, (img_height, img_width)) for x in aug_masks]
# Out:
#   3%|▎         | 6/203 [00:00<00:03, 56.00it/s]
# Loading images.
# 100%|██████████| 203/203 [00:03<00:00, 67.25it/s]
# Loading masks.
# 100%|██████████| 203/203 [00:00<00:00, 358050.34it/s]
#   0%|          | 0/203 [00:00<?, ?it/s]/home/ajuska/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   1%|          | 2/203 [00:00<00:11, 17.45it/s]
# Preprocessing images.
#
# Extending database.
#  18%|█▊        | 37/203 [00:03<00:11, 13.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-285162798380> in <module>
#       9
#      10 data_augmentor = DataAugmentation(imgs_masks, how_many=1)
# ---> 11 aug_imgs, aug_masks = data_augmentor.extend_database()
#      12
#      13 trainX = [cv2.resize(x, (img_height, img_width)) for x in aug_imgs]
#
# ~/Dokumenty/Skola/unet_implementation/vessel_segmentation/unet_project/data_augmentation.py in extend_database(self)
#      63                                                                      vertical_flipped_mask)
#      64                 rotated_img, rotated_mask = self._random_rotate(cropped_img, cropped_mask)
# ---> 65                 resized_img, resized_mask = self._resize(rotated_img, rotated_mask)
#      66
#      67                 self._output_images.append(resized_img)
#
# ~/Dokumenty/Skola/unet_implementation/vessel_segmentation/unet_project/data_augmentation.py in _resize(self, img, mask)
#      43     def _resize(self, img, mask):
#      44         _size = (np.random.randint(4, 2 * img.shape[0]), np.random.randint(4, 2 * img.shape[1]))
# ---> 45         return resize(img, _size, mode='constant', preserve_range=True), \
#      46                resize(mask, _size, mode='constant', preserve_range=True)
#      47
#
# ~/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/skimage/transform/_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     167         out = warp(image, tform, output_shape=output_shape, order=order,
#     168                    mode=mode, cval=cval, clip=clip,
# --> 169                    preserve_range=preserve_range)
#     170
#     171     else:  # n-dimensional interpolation
#
# ~/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/skimage/transform/_warps.py in warp(image, inverse_map, map_args, output_shape, order, mode, cval, clip, preserve_range)
#     850                     dims.append(_warp_fast(image[..., dim], matrix,
#     851                                            output_shape=output_shape,
# --> 852                                            order=order, mode=mode, cval=cval))
#     853                 warped = np.dstack(dims)
#     854
#
# skimage/transform/_warps_cy.pyx in skimage.transform._warps_cy._warp_fast()
#
# ~/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     431
#     432
# --> 433 def asarray(a, dtype=None, order=None):
#     434     """Convert the input to an array.
#     435
#
# KeyboardInterrupt:

# %%
trainX = np.array([x/255 for x in trainX])
trainY = np.array([np.expand_dims(x/255, axis=-1) for x in trainY])

# %%
trainY.shape
# Out:
# (406, 224, 224, 1)

# %%
plt.figure()
plt.imshow(trainX[110])
plt.figure()
plt.imshow(np.squeeze(trainY[110]), cmap='gray')

# %%
unet = Unet(img_height=img_height, img_width=img_width, img_channels=img_channels)
model = unet.create_model()
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-test.h5', verbose=1, save_best_only=True)
results = model.fit(trainX, trainY, validation_split=0.1, batch_size=32, epochs=10,
                    callbacks=[earlystopper, checkpointer])
# Out:
# Creating model.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-80dff49716be> in <module>
#       4 checkpointer = ModelCheckpoint('model-test.h5', verbose=1, save_best_only=True)
#       5 results = model.fit(trainX, trainY, validation_split=0.1, batch_size=32, epochs=10,
# ----> 6                     callbacks=[earlystopper, checkpointer])
#
# ~/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     787                 feed_output_shapes,
#     788                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 789                 exception_prefix='target')
#     790
#     791             # Generate sample-wise weight values given the `sample_weight` and
#
# ~/Dokumenty/Skola/diplomka/diplomka/lib/python3.5/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     126                         ': expected ' + names[i] + ' to have ' +
#     127                         str(len(shape)) + ' dimensions, but got array '
# --> 128                         'with shape ' + str(data_shape))
#     129                 if not check_batch_axis:
#     130                     data_shape = data_shape[1:]
#
# ValueError: Error when checking target: expected conv2d_19 to have 4 dimensions, but got array with shape (406, 224, 224)
