# %% [markdown]
# # Vessels segmentation - UNET

# %%
import sys
sys.path.append('..')

# %%
import os
import cv2
from matplotlib import pyplot as plt
import numpy as np

from segmentation_models import Unet, Linknet
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score
from segmentation_models.backbones import get_preprocessing

from classes.image_utils import ImageUtils
from classes.data_generator import DataGenerator
from classes.metrics import Metrics
from classes.model_utils import ModelUtils
from classes.create_patches import PatchesCreator
from classes.visualize import VisualizeUtils
from classes.process_results import ProcessResults

# %% [markdown]
# ## Initialize

# %%
train_frame_path = '/home/andrea/learning/vessel_segmentation/custom_train/train_imgs/train/'
train_mask_path = '/home/andrea/learning/vessel_segmentation/custom_train/train_masks/train'

val_frame_path = '/home/andrea/learning/vessel_segmentation/custom_train/val_imgs/val'
val_mask_path = '/home/andrea/learning/vessel_segmentation/custom_train/val_masks/val'

img_height = 256
img_width = 256
img_channels = 3

no_train_imgs = len(os.listdir(train_frame_path))
no_val_imgs = len(os.listdir(val_frame_path))

epochs = 1
batch_size = 1

backbone = 'resnet18'
preprocess_input = get_preprocessing(backbone)
image_ut = ImageUtils(train_frame_path, train_mask_path, img_height, img_width, architecture='unet')

# %% [markdown]
# ## Create data generators

# %%
train_gen = DataGenerator(train_frame_path, train_mask_path, img_height, img_width, backbone, batch_size, seg_region='vessels')
val_gen = DataGenerator(val_frame_path, val_mask_path, img_height, img_width, backbone, batch_size, patches=True)
train_data_generator = train_gen.data_generate()
val_data_generator = val_gen.data_generate()

# %% [markdown]
# ## Define model and fit

# %%
model = Unet(backbone, classes=1, activation='sigmoid', encoder_weights='imagenet')
model.compile('Adam', loss=[Metrics.dice_coef_loss], metrics=[Metrics.dice_coef, 'accuracy'])
model.summary()

results = model.fit_generator(train_data_generator, 
                              epochs=epochs, 
                              steps_per_epoch=(no_train_imgs*6//batch_size),
                              validation_data=val_data_generator, 
                              validation_steps=(no_val_imgs*6//batch_size), 
                              verbose=1)
# Out:
# WARNING:tensorflow:From /home/andrea/env/diplomka3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# data (InputLayer)               (None, None, None, 3 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, None, None, 3 9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           bn_data[0][0]
# ...

# %%
ModelUtils.save_model("model_unet_vessels_pretrainedRESNET18_150noeqa_patches", model)

# %% [markdown]
# ## Plot loss curve and save model

# %%
VisualizeUtils.plot_learning_curve(results)

# %% [markdown]
# ## Test and display results

# %%
test_img, test_mask = image_utils_test.load_image_mask_pair('Study_02_00125_02_L_registered.avi_average_image.tif')

patches_creator_test = PatchesCreator(img_height, img_width)
img_patches, mask_patches = patches_creator_test.create_patches(test_img, test_mask)
# Out:
# Creating patches.

# %%
predicted_patches = []

for idx in range(len(img_patches)):
    resized_img, resized_mask = image_utils_test.preprocess_image_mask_pair(img_patches[idx], mask_patches[idx])
    predicted_img = process_results_test.predict_image(resized_img/255, resized_mask/255,  model)
    predicted_patches.append(predicted_img)

# %%
_, dims, m_w, m_h = _modulo_image(test_img)
rec_mask = compose_img(predicted_patches, dims, m_h, m_w, mode='mask')

# %%
VisualizeUtils.plot_result_single_image(test_img, test_mask, rec_mask)
