# %% [markdown]
# # Test models

# %%
import os  
import random
import cv2
import numpy as np
from matplotlib import pyplot as plt
from segmentation_models.backbones import get_preprocessing

from unet_project.disk_functions import load_model, predict_images, plot_images
from unet_project.image_utils import ImageUtils
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.5/dist-packages/classification_models/resnext/__init__.py:4: UserWarning: Current ResNext models are deprecated, use keras.applications ResNeXt models
#   warnings.warn('Current ResNext models are deprecated, '

# %% [markdown]
# ### Initialize

# %%
val_frame_path = '/mnt/data/aja/diplomka/disk/val_imgs/val'
val_mask_path = '/mnt/data/aja/diplomka/disk/val_masks/val'
img_height = 512
img_width = 512

image_ut = ImageUtils(val_frame_path, val_mask_path, img_height, img_width, architecture='unet')

# %% [markdown]
# ## VGG19
# - backbone: VGG19
# - optimizier: Adam
# - epochs: 50
# - pretrained: True
# - equalized: False
# - loss function: dice
# - preprocessed: False

# %%
modelVGG19_dice = load_model('model_unet_disk_pretrainedVGG19_dice6')
imgs_VGG19_dice, masks_VGG19_dice, predicted_imgs_VGG19_dice = predict_images(backbone='vgg19', 
                                                                                val_frame_path=val_frame_path,
                                                                                model=modelVGG19_dice,
                                                                                preprocess=False)
plot_images(imgs_VGG19_dice, masks_VGG19_dice, predicted_imgs_VGG19_dice)
# Out:
# Loaded model from disk

# %% [markdown]
# ## VGG19
# - backbone: VGG19
# - optimizier: SGD
# - epochs: 50
# - pretrained: True
# - equalized: False
# - loss function: dice
# - preprocessed: False

# %%
modelVGG19_SGDdice = load_model('model_unet_disk_pretrainedVGG19_SGDdice6')
imgs_VGG19_SGDdice, masks_VGG19_SGDdice, predicted_imgs_VGG19_SGDdice = predict_images(backbone='vgg19', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=modelVGG19_SGDdice,
                                                                                         preprocess=False)
plot_images(imgs_VGG19_SGDdice, masks_VGG19_SGDdice, predicted_imgs_VGG19_SGDdice)
# Out:
# Loaded model from disk

# %% [markdown]
# ## RESNET18
# - backbone: Resnet18
# - optimizier: Adam
# - epochs: 200
# - pretrained: True
# - equalized: True
# - loss function: dice
# - preprocessed: True

# %%
# modelRESNET18_dice.compile('Adam', loss=dice_coef_loss, metrics=["accuracy", dice_coef])
# modelRESNET18_dice.evaluate(np.array(imgs_RESNET18_dice), np.array(masks_RESNET18_dice), verbose=1)

# %%
modelRESNET18_dice = load_model('model_unet_disk_pretrainedRESNET18_200eqa')
imgs_RESNET18_dice, masks_RESNET18_dice, predicted_imgs_RESNET18_dice = predict_images(backbone='resnet18', 
                                                                                      val_frame_path=val_frame_path,
                                                                                      model=modelRESNET18_dice,
                                                                                      preprocess=True)
plot_images(imgs_RESNET18_dice, masks_RESNET18_dice, predicted_imgs_RESNET18_dice)
# Out:
# Loaded model from disk

# %% [markdown]
# ## RESNET34
# - backbone: Resnet34
# - optimizier: Adam
# - epochs: 200
# - pretrained: True
# - equalized: True
# - loss function: dice
# - preprocessed: True

# %%
modelRESNET34_dice = load_model('model_unet_disk_pretrainedRESNET34_200eqa')
imgs_RESNET34_dice, masks_RESNET34_dice, predicted_imgs_RESNET34_dice = predict_images(backbone='resnet34', 
                                                                                      val_frame_path=val_frame_path,
                                                                                      val_mask_path=val_mask_path,
                                                                                      model=modelRESNET34_dice,
                                                                                      preprocess=True)
plot_images(imgs_RESNET34_dice, masks_RESNET34_dice, predicted_imgs_RESNET34_dice)
# Out:
# Loaded model from disk

# %% [markdown]
# ## RESNET18
# - backbone: Resnet18
# - optimizier: Adam
# - epochs: 200
# - pretrained: True
# - equalized: False
# - loss function: dice
# - preprocessed: True

# %%
modelRESNET18_noeqa = load_model('model_unet_disk_pretrainedRESNET18_200noeqa')
imgs_RESNET18_noeqa, masks_RESNET18_noeqa, predicted_imgs_RESNET18_noeqa = predict_images(backbone='resnet18', 
                                                                                      val_frame_path=val_frame_path,
                                                                                      val_mask_path=val_mask_path,
                                                                                      model=modelRESNET18_noeqa,
                                                                                      preprocess=True)
plot_images(imgs_RESNET18_noeqa, masks_RESNET18_noeqa, predicted_imgs_RESNET18_noeqa)
# Out:
# Loaded model from disk

# %% [markdown]
# ## RESNET34
# - backbone: Resnet34
# - optimizier: Adam
# - epochs: 200
# - pretrained: True
# - equalized: False
# - loss function: dice
# - preprocessed: True

# %%
modelRESNET34_noeqa = load_model('model_unet_disk_pretrainedRESNET34_200noeqa')
imgs_RESNET34_noeqa, masks_RESNET34_noeqa, predicted_imgs_RESNET34_noeqa = predict_images(backbone='resnet34', 
                                                                                      val_frame_path=val_frame_path,
                                                                                      val_mask_path=val_mask_path,
                                                                                      model=modelRESNET34_noeqa,
                                                                                      preprocess=True)
plot_images(imgs_RESNET34_noeqa, masks_RESNET34_noeqa, predicted_imgs_RESNET34_noeqa)
# Out:
# Loaded model from disk

# %% [markdown]
# ## RESNET18 SGD
# - backbone: Resnet18
# - optimizier: SGD
# - epochs: 200
# - pretrained: True
# - equalized: True
# - loss function: dice
# - preprocessed: True

# %%
modelRESNET18_SGD = load_model('model_unet_disk_pretrainedRESNET18_200eqa_SGD')
imgs_RESNET18_SGD, masks_RESNET18_SGD, predicted_imgs_RESNET18_SGD = predict_images(backbone='resnet18', 
                                                                                      val_frame_path=val_frame_path,
                                                                                      model=modelRESNET18_SGD,
                                                                                      preprocess=True)
plot_images(imgs_RESNET18_SGD, masks_RESNET18_SGD, predicted_imgs_RESNET18_SGD)
# Out:
# Loaded model from disk

# %% [markdown]
# ## RESNET50 Adam dice

# %%
modelRESNET50_dice = load_model('model_unet_disk_pretrainedRESNET50_6')
imgs_RESNET50_dice, masks_RESNET50_dice, predicted_imgs_RESNET50_dice = predict_images(backbone='resnet50', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=modelRESNET50_dice,
                                                                                         preprocess=True)
plot_images(imgs_RESNET50_dice, masks_RESNET50_dice, predicted_imgs_RESNET50_dice)
# Out:
# Loaded model from disk

# %% [markdown]
# # Adam Resnet 101 - 200 epoch

# %%
modelRESNET101_200 = load_model('model_unet_disk_pretrainedRESNET101_200')
imgs_RESNET101_200, masks_RESNET101_200, predicted_imgs_RESNET101_200 = predict_images(backbone='resnet101', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=modelRESNET101_200,
                                                                                         preprocess=True)
plot_images(imgs_RESNET101_200, masks_RESNET101_200, predicted_imgs_RESNET101_200)
# Out:
# Loaded model from disk

# %% [markdown]
# # Adam Resnet 152

# %%
modelRESNET152_dice = load_model('models/model_unet_disk_pretrainedRESNET152')
imgs_RESNET152_dice, masks_RESNET152_dice, predicted_imgs_RESNET152_dice = predict_images(backbone='resnet152', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=modelRESNET152_dice,
                                                                                         preprocess=True)
plot_images(imgs_RESNET152_dice, masks_RESNET152_dice, predicted_imgs_RESNET152_dice)
# Out:
# Loaded model from disk

# %% [markdown]
# # Adam Inception Resnet

# %%
modelINC_RES_dice = load_model('models/model_unet_disk_pretrainedINCEPTION_RESNET')
imgs_INC_RES_dice, masks_INC_RES_dice, predicted_imgs_INC_RES_dice = predict_images(backbone='inceptionresnetv2', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=modelINC_RES_dice,
                                                                                         preprocess=False)
plot_images(imgs_INC_RES_dice, masks_INC_RES_dice, predicted_imgs_INC_RES_dice)
# Out:
# Loaded model from disk

# %% [markdown]
# # Adam inception

# %%
model_INCEPTION_dice = load_model('models/model_unet_disk_pretrainedINCEPTION')
imgs_INCEPTION_dice, masks_INCEPTION_dice, predicted_imgs_INCEPTION_dice = predict_images(backbone='inceptionv3', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=model_INCEPTION_dice,
                                                                                         preprocess=True)
plot_images(imgs_INCEPTION_dice, masks_INCEPTION_dice, predicted_imgs_INCEPTION_dice)
# Out:
# Loaded model from disk
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # SGD Resnet 18

# %%
model_RESNET_SGD_dice = load_model('models/model_unet_disk_pretrainedRESNET18_SGD')
imgs_INCEPTION_dice, masks_INCEPTION_dice, predicted_imgs_INCEPTION_dice = predict_images(backbone='inceptionv3', 
                                                                                         val_frame_path=val_frame_path,
                                                                                         model=model_INCEPTION_dice,
                                                                                         preprocess=True)
plot_images(imgs_INCEPTION_dice, masks_INCEPTION_dice, predicted_imgs_INCEPTION_dice)
